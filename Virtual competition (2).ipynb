# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
data=pd.DataFrame(data,index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
data
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
data.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
data.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
data[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
data1=data[['animal','age']]
data1.loc[["b","e","d"]]
# Out:
#   animal  age
# b    cat  3.0
# e    dog  5.0
# d    dog  NaN

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
data[(data['visits']>3)]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
data[(data['age']).isnull()]
# Out:
#   animal  age  visits  priority
# d    dog  NaN       3      True
# h    cat  NaN       1      True

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
data1=data1[(data['animal']=="cat")]
data1=data1[(data['age']<3.0)]
data1
# Out:
# <ipython-input-58-c165156edf85>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data1=data1[(data['animal']=="cat")]
# <ipython-input-58-c165156edf85>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data1=data1[(data['age']<3.0)]
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
data[(data['age']<=2)&(data['age']<=4)]
# Out:
#   animal  age  visits priority
# c  snake  0.5       2       no
# f    cat  2.0       3       no

# %%
data["age"] = data["age"].replace(["snake"], "python")
data
# Out:
#    animal  age  visits  priority
# i     dog  7.0       2     False
# e     dog  5.0       2     False
# g  python  4.5       1     False
# b     cat  3.0       3      True
# j     dog  3.0       1     False
# a     cat  2.5       1      True
# f     cat  2.0       3     False
# c  python  0.5       2     False
# d     dog  NaN       3      True
# h     cat  NaN       1      True

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
data['visits'].sum()
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
data4=data.groupby('animal')[['age']].mean()
data4
# Out:
#         age
# animal
# cat     2.5
# dog     5.0
# snake   2.5

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
k={'animal':'cat','age':3,'visits':2,'priority':'yes'}
k1=pd.DataFrame(k)
df1=pd.concat([data, k])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-53998af4094f> in <cell line: 2>()
#       1 k={'animal':'cat','age':3,'visits':2,'priority':'yes'}
# ----> 2 k1=pd.DataFrame(k)
#       3 df1=pd.concat([data, k])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
data.groupby('animal').count()
# Out:
#         age  visits  priority
# animal
# cat       3       4         4
# dog       3       4         4
# snake     2       2         2

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
data.sort_values(by=['age', 'visits'],
               ascending=[False, True])
# Out:
#    animal  age  visits  priority
# i     dog  7.0       2     False
# e     dog  5.0       2     False
# g  python  4.5       1     False
# j     dog  3.0       1     False
# b     cat  3.0       3      True
# a     cat  2.5       1      True
# f     cat  2.0       3     False
# c  python  0.5       2     False
# h     cat  NaN       1      True
# d     dog  NaN       3      True

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
data["priority"] = data["priority"].replace(["yes"], True)
data["priority"] = data["priority"].replace(["no"], False)
data
# Out:
#    animal  age  visits  priority
# i     dog  7.0       2     False
# e     dog  5.0       2     False
# g  python  4.5       1     False
# b     cat  3.0       3      True
# j     dog  3.0       1     False
# a     cat  2.5       1      True
# f     cat  2.0       3     False
# c  python  0.5       2     False
# d     dog  NaN       3      True
# h     cat  NaN       1      True

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
data["animal"] = data["animal"].replace(["snake"], "python")
data
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c  python  0.5       2       no
# d     dog  NaN       3      yes
# e     dog  5.0       2       no
# f     cat  2.0       3       no
# g  python  4.5       1       no
# h     cat  NaN       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
df=pd.read_csv("/content/ny-flights.csv")
df
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
df1=df['airline_id'].value_counts()
df1.idxmax()
# Out:
# 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt
plt.plot(df['arr_delay'],df['dep_delay'])
plt.xlabel('arr_delay')
plt.ylabel('dep_delay')
plt.title('delay')
# Out:
# Text(0.5, 1.0, 'delay')
